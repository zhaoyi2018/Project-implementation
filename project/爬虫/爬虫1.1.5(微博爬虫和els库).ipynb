# %%
#!/usr/bin/python 
# -*- coding: utf-8 -*-
# !pip install bs4==0.0.1
# !pip install elasticsearch==7.10.0
# Out:
# Requirement already satisfied: bs4==0.0.1 in /opt/venv/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/venv/lib/python3.7/site-packages (from bs4==0.0.1) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /opt/venv/lib/python3.7/site-packages (from beautifulsoup4->bs4==0.0.1) (2.0.1)
# Requirement already satisfied: elasticsearch==7.10.0 in /opt/venv/lib/python3.7/site-packages (7.10.0)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /opt/venv/lib/python3.7/site-packages (from elasticsearch==7.10.0) (1.26.2)
# Requirement already satisfied: certifi in /opt/venv/lib/python3.7/site-packages (from elasticsearch==7.10.0) (2020.11.8)

# %%
def random_sleep():
    from random import randint
    from time import sleep
    sleep_time = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.5, 1.6, 1.7, 1.8, 1.9, 2.0]
    index = randint(0, len(sleep_time)-1)
    sleep(sleep_time[index])

# %%
def random_header():
    from random import randint
    header_list = [
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.835.163 Safari/535.1",
    "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:6.0) Gecko/20100101 Firefox/6.0",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50",
    "Opera/9.80 (Windows NT 6.1; U; zh-cn) Presto/2.9.168 Version/11.50",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 2.0.50727; SLCC2; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; Tablet PC 2.0; .NET4.0E)",
    "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; InfoPath.3)",
    "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB7.0)",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)",
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)",
    "Mozilla/5.0 (Windows; U; Windows NT 6.1; ) AppleWebKit/534.12 (KHTML, like Gecko) Maxthon/3.0 Safari/534.12",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; .NET4.0E)",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; .NET4.0E; SE 2.X MetaSr 1.0)",
    "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.3 (KHTML, like Gecko) Chrome/6.0.472.33 Safari/534.3 SE 2.X MetaSr 1.0",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; .NET4.0E)",
    "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/13.0.782.41 Safari/535.1 QQBrowser/6.9.11079.201",
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.3; .NET4.0C; .NET4.0E) QQBrowser/6.9.11079.201",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)"]
    index = randint(0, len(header_list)-1)
    return {"user-agent":header_list[index]}

# %%
def re_filter(content):
    '''
    使用re工具, 处理冗余信息
    '''
    import re

    pattern1 = re.compile(r'#[^#]+#')
    pattern2 = re.compile(r"[a-zA-Z]")
    return re.sub(pattern2, "", re.sub(pattern1, "", content))

# %%
def get_info(res, title_name="", get_content=True):
    '''
    处理json数据, 获取指定的内容(题目和评论)或其他内容
    '''
    from bs4 import BeautifulSoup
    from time import sleep

    if res.status_code != 200 or res.json()["ok"] != 1:
        print("ip被封!, 等候20s")
        sleep(20)
        if get_content:
            return -1, 0
        else:
            return []
    contents_dict = res.json()["data"]
    if get_content:
        # 判断是否为浏览页
        ## 如果是
        if "max_id" not in contents_dict:
            mid_list = []
            for item in contents_dict["cards"]:
                # 如果mid_list大于2, 就跳出
                if len(mid_list)>=3:
                    break
                # 判断评论类型
                if item["card_type"] != 9:
                    continue
                # 获取mid
                mid_list.append(item["mblog"]["id"])
            return 1, mid_list
        else:  
        # 如果不是
            contents_list = []
            # 获取下一页
            max_id = contents_dict["max_id"]

            month_dict = {"Jan":"01", "Feb":"02", "Mar":"03", "Apr":"04", "May":"05", "Jun":"06", "Jul":"07","Aug":"08", "Sep":"09", "Oct":"10","Nov":"11","Dec":"12"}
            for item in contents_dict["data"]:

                # 获取评论内容和时间
                content = item["text"]
                time_list = item["created_at"].split(" ")
                created_time = "{}-{}-{}".format(time_list[-1], month_dict[time_list[1]], time_list[2])

                # 使用beautifulSoup
                bf = BeautifulSoup(content)
                content = ""
                for p in bf.stripped_strings:
                    content += p
                
                # 使用re工具, 将##内容全部清除
                content = re_filter(content)
                if content=="" or "转发" in content:
                    continue
                contents_list.append((title_name, content, created_time))
            return max_id, contents_list
    else:
        ## 获取es库已存在title
        old_title = all_es_search(key="title")

        keyword_list = []
        for item in contents_dict["cards"][0]["card_group"]:
            keyword = str(item["desc"])
            if keyword not in old_title:
                keyword_list.append(keyword)
        return keyword_list

# %%
def push_es(content_list):
    '''
    将数据推入云es库中
    '''
    # 考虑列表为空时, 直接跳出
    if len(content_list)==0:
        return
    
    # 列表非空时, 开始推入
    from elasticsearch import Elasticsearch
    from elasticsearch import helpers
    # 开始连接es库(感觉这里可以优化)
    es = Elasticsearch(
        ['es-cn-09k1xdlqf000a7yyn.public.elasticsearch.aliyuncs.com'],
        http_auth=('elastic', 'Zy13720028637'),
        port=9200,
        use_ssl=False
    )
    # 判断数据是否为字典类型
    if type(content_list[0]) != dict:
        names = ["title", "describe", "createData"]
        for i, data in enumerate(content_list):
            temp_dict = {}
            for index, content in enumerate(data):
                temp_dict[names[index]] = content
            content_list[i] = temp_dict
    # 将数据修饰一下
    action = ({
        "_index":"hot_news",
        "_type":"comment",
        "_source":data
    } for data in content_list)
    # 导入数据
    helpers.bulk(es, action, request_timeout=30)

# %%
def web_grap(keyword):
    '''
    网页抓取
    '''
    import requests
    import pandas as pd
    
    base_url = "https://m.weibo.cn/api/container/getIndex?containerid=100103type%3D1%26q%3D%23{}%23&page_type=searchall&page={}"
    # headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 Edg/86.0.622.63"}
    print("\n抓取热度:{}".format(keyword))

    # 第一步抓取热点公众号
    while True:
        url = base_url.format(keyword, 0)
        random_sleep()
        res = requests.get(url.format(keyword, 1), headers=random_header())
        status, mid_list = get_info(res)
        # 判断ip是否被封
        if status==-1:
            print("再次申请...")
            continue
        else:
            break
    
    base_url = "https://m.weibo.cn/comments/hotflow?id={}&mid={}&max_id={}"
    max_id = 0
    num = 0
    cookie = {"Cookie":"_T_WM=31420914776;M_WEIBOCN_PARAMS=luicode%3D20000174 ;WEIBOCN_FROM=1110006030; XSRF-TOKEN=6456fc; MLOGIN=1 ;SUB=_2A25yuiimDeRhGeRO61IS9yvLyT-IHXVuRUjurDV6PUJbkdANLWrjkW1NUIeUSgyof564-cNUpoux4c760jBpCOPX"}
    for i in range(len(mid_list)):
        flag = 0
        while True:
            # 正常抓取
            url = base_url.format(mid_list[i], mid_list[i], max_id)
            # print(url)
            random_sleep()
            res = requests.get(url, cookies=cookie, headers=random_header())
            temp, contents_list = get_info(res, keyword)

            # 判断ip是否被封
            if temp ==-1:
                flag += 1
                if flag == 3:
                    print("  跳出此次申请...")
                    break
                print("  再次申请...")
                continue
            flag = 0
            num += len(contents_list)
            max_id = temp

            ## 存储数据到es中
            push_es(contents_list)
            print(" 已抓取{}条评论!!".format(num))

            # 判断是否满足跳出条件
            if max_id == 0:
                break
    print("{}抓取结束!".format(keyword))

# %%
def to_more_grap():
    '''
    用于获取相关热度的关键词
    '''
    import requests
    
    # 准备网站
    # base_url = "https://m.weibo.cn/api/container/getIndex?containerid=231583&page_type=searchall"
    base_url = "https://m.weibo.cn/api/container/getIndex?containerid=106003type%3D25%26t%3D3%26disable_hot%3D1%26filter_type%3Drealtimehot&title=%E5%BE%AE%E5%8D%9A%E7%83%AD%E6%90%9C&extparam=seat%3D1%26pos%3D0_0%26mi_cid%3D100103%26cate%3D10103%26filter_type%3Drealtimehot%26c_type%3D30%26display_time%3D1606374389&luicode=10000011&lfid=231583"
    cookie = {"Cookie":"_T_WM=31420914776;M_WEIBOCN_PARAMS=luicode%3D20000174 ;WEIBOCN_FROM=1110006030; XSRF-TOKEN=6456fc; MLOGIN=1 ;SUB=_2A25yuiimDeRhGeRO61IS9yvLyT-IHXVuRUjurDV6PUJbkdANLWrjkW1NUIeUSgyof564-cNUpoux4c760jBpCOPX"}
    
    ## 准备https头部
    # headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 Edg/86.0.622.63"}
    # ## 睡眠
    random_sleep()
    ## 开始访问
    res = requests.get(base_url, headers=random_header(), cookies=cookie)
    ## 处理json数据, 获取更多问题号
    contents_list = get_info(res, get_content=False)
    return contents_list

# %%
def set_grap(question_num=1):
    '''
    集成爬虫
    '''
    # 爬取关键词
    keyword_list = to_more_grap()
    web_grap(keyword_list[0])
    question_num -= 1

    i = 1
    while question_num:
        temp_i = i
        while len(keyword_list) <= i:
            keyword_list += to_more_grap()
            keyword_list = sorted(set(keyword_list),key=keyword_list.index)
            temp_i -= 1
            if temp_i == -1:
                print("因热度关键词一致, 故抓取结束!")
                return
        web_grap(keyword_list[i])
        i += 1
        question_num -= 1
    print("抓取任务结束!")

# %%
def weibo_grap(num=5):
    set_grap(num)

# %%
def all_es_search(key="title", search=""):
    '''
    输入某一属性, 返回所有不同值的list
    '''
    from elasticsearch import Elasticsearch
    # 开始连接es库(感觉这里可以优化)
    es = Elasticsearch(
        ['es-cn-09k1xdlqf000a7yyn.public.elasticsearch.aliyuncs.com'],
        http_auth=('elastic', 'Zy13720028637'),
        port=9200,
        use_ssl=False
    )
    
    # 开始查询(这里绝对可以优化, 先简单实现)
    if len(search) == 0:
        dsl = {
            "size": 0,
            "query":{
                "match_all":{}
            },
            "aggs": {
                "source": {
                    "terms": {
                        "field": "{}.raw".format(key)
                    }
                }
            }
        }
    else:
        dsl = {
            "size": 0,
            "query":{
                "match_phrase":{
                    "title":search
                }
            },
            "aggs": {
                "source": {
                    "terms": {
                        "field": "{}.raw".format(key)
                    }
                }
            }
        }

    result = es.search(index='hot_news', doc_type='comment', body=dsl, timeout="30s", ignore=400)

    if "error" in result:
        print("题目列表, 申请失败! 返回空列表")
        return []
    
    mdata = result.get("aggregations").get("source").get("buckets")
        
    if not mdata:
        return []
    
    search_list = []
    for item in mdata:
        search_list.append(item["key"])
    return search_list

# %%
def es_search(search_in, stype="match", source=("title", )):
    '''
    根据search_in(指定字符串)查找相关问题, 并返回全部内容
    '''
    from elasticsearch import Elasticsearch
    # 开始连接es库(感觉这里可以优化)
    es = Elasticsearch(
        ['es-cn-09k1xdlqf000a7yyn.public.elasticsearch.aliyuncs.com'],
        http_auth=('elastic', 'Zy13720028637'),
        port=9200,
        use_ssl=False
    )
    
    # 开始查询(这里绝对可以优化, 先简单实现)
    dsl = {
        "_source" : list(source),
        'query': {
            stype : {
                'title': search_in
            }
        }
    }

    result = es.search(index='hot_news', doc_type='comment', body=dsl, scroll="30s", size=100, timeout="30s")
    mdata = result.get("hits").get("hits")
        
    if not mdata:
        print('empty')
        return []
    scroll_id = result["_scroll_id"]
    total = result["hits"]["total"]
    for i in range(int(total/100)):
        res = es.scroll(scroll_id=scroll_id,scroll='30s')
        mdata = mdata + res["hits"]["hits"]
    return mdata

# %%
def get_search_info(content, source=("title",)):
    '''
    先简单一点, 就获取相关问题title
    '''
    data_list = []
    source_list = list(source)
    for data in content:
        source = data["_source"]
        temp_list = []
        for name in source_list:
            temp_list.append(source[name])
        
        # 保证数据维度尽量不多
        if len(temp_list)==1:
            data_list.append(temp_list[0])
        else:
             data_list.append(temp_list)
    return data_list

# %%
def title_print(content_info):
    '''
    简单实现, 就打印含有title的列表
    '''
    print("  搜索结果:")
    for index, title in enumerate(content_info):
        print("    {}. {}".format(index+1, title))
    if len(content_info)==0:
        print("  未搜索相关结果!")

# %%
def save_csv(content_info, names=("price", "describe")):
    '''
    将列表数据转换为csv数据存储
    '''
    import pandas as pd
    content_info = [[0, x] for x in content_info if x!=""]
    dataset = pd.DataFrame(content_info, columns=names)
    dataset.to_csv("bad2.csv", index=None, sep="\t")

# %%
def weibo_search():
    # 输入相关查询
    search_in = input()
    # 从es库查询结果
    content = all_es_search(search=search_in)
    # 打印内容
    title_print(content)

    # 二级执行菜单
    print("\n------二级执行菜单------")
    print("1. 选择指定题目")
    print("2. 返回一级菜单")
    select_num = int(input())
    if select_num==1:
        print("请选择:")
        title_num = int(input())
        content = es_search(content_info[title_num-1], stype="match_phrase", source=("describe",))
        content_info = get_search_info(content, source=("describe",))
        print("数据数量:{}".format(len(content_info)))
        # save_csv(content_info)
    else:
        return 0

# %%
def main():
    while True:
        print("\n------一级执行菜单------")
        print("1. 简单抓取")
        print("2. 相关搜索")
        print("3. 退出程序")
        select_num = int(input())
        if select_num==1:
            weibo_grap(20)
        elif select_num==2:
            print("请输入内容:")
            weibo_search()
        else:
            print("成功退出!")
            break

# %%
weibo_grap(20)
# Out:
# 抓取热度:多部委提方案消除老年数字鸿沟
#  已抓取19条评论!!
#  已抓取37条评论!!
#  已抓取55条评论!!
#  已抓取73条评论!!
#  已抓取93条评论!!
#  已抓取111条评论!!
#  已抓取129条评论!!
#  已抓取148条评论!!
#  已抓取168条评论!!
#  已抓取187条评论!!
#  已抓取201条评论!!
#  已抓取206条评论!!
#  已抓取214条评论!!
#  已抓取220条评论!!
#  已抓取225条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取245条评论!!
#  已抓取265条评论!!
#  已抓取285条评论!!
#  已抓取304条评论!!
#  已抓取320条评论!!
#  已抓取339条评论!!
#  已抓取358条评论!!
#  已抓取378条评论!!
#  已抓取396条评论!!
#  已抓取410条评论!!
#  已抓取429条评论!!
#  已抓取447条评论!!
#  已抓取466条评论!!
#  已抓取484条评论!!
#  已抓取491条评论!!
#  已抓取495条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取513条评论!!
#  已抓取513条评论!!
# 多部委提方案消除老年数字鸿沟抓取结束!
#
# 抓取热度:李现 我有点无法fu吸
#  已抓取18条评论!!
#  已抓取37条评论!!
#  已抓取56条评论!!
#  已抓取75条评论!!
#  已抓取93条评论!!
#  已抓取109条评论!!
#  已抓取126条评论!!
#  已抓取145条评论!!
#  已抓取163条评论!!
#  已抓取182条评论!!
#  已抓取200条评论!!
#  已抓取218条评论!!
#  已抓取237条评论!!
#  已抓取257条评论!!
#  已抓取275条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取295条评论!!
#  已抓取315条评论!!
#  已抓取335条评论!!
#  已抓取354条评论!!
#  已抓取372条评论!!
#  已抓取388条评论!!
#  已抓取406条评论!!
#  已抓取424条评论!!
#  已抓取442条评论!!
#  已抓取462条评论!!
#  已抓取480条评论!!
#  已抓取499条评论!!
#  已抓取516条评论!!
#  已抓取535条评论!!
#  已抓取553条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取573条评论!!
#  已抓取592条评论!!
#  已抓取602条评论!!
# 李现 我有点无法fu吸抓取结束!
#
# 抓取热度:钟南山称已出现同患流感和新冠病例
#  已抓取20条评论!!
#  已抓取40条评论!!
#  已抓取60条评论!!
#  已抓取80条评论!!
#  已抓取100条评论!!
#  已抓取117条评论!!
#  已抓取134条评论!!
#  已抓取154条评论!!
#  已抓取172条评论!!
#  已抓取189条评论!!
#  已抓取209条评论!!
#  已抓取227条评论!!
#  已抓取247条评论!!
#  已抓取266条评论!!
#  已抓取285条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取289条评论!!
#  已抓取294条评论!!
#  已抓取296条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
# 钟南山称已出现同患流感和新冠病例抓取结束!
#
# 抓取热度:金鸡奖手机电影计划
#  已抓取16条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取34条评论!!
#  已抓取38条评论!!
#  已抓取40条评论!!
#  已抓取59条评论!!
#  已抓取78条评论!!
#  已抓取80条评论!!
# 金鸡奖手机电影计划抓取结束!
#
# 抓取热度:张艺谋说刘浩存是周冬雨接班人
#  已抓取20条评论!!
#  已抓取40条评论!!
#  已抓取59条评论!!
#  已抓取79条评论!!
#  已抓取98条评论!!
#  已抓取117条评论!!
#  已抓取137条评论!!
#  已抓取157条评论!!
#  已抓取176条评论!!
#  已抓取196条评论!!
#  已抓取216条评论!!
#  已抓取236条评论!!
#  已抓取254条评论!!
#  已抓取265条评论!!
#  已抓取278条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取298条评论!!
#  已抓取299条评论!!
#  已抓取319条评论!!
#  已抓取339条评论!!
#  已抓取354条评论!!
#  已抓取357条评论!!
#  已抓取358条评论!!
# 张艺谋说刘浩存是周冬雨接班人抓取结束!
#
# 抓取热度:四川为了丁真有多努力
#  已抓取20条评论!!
#  已抓取40条评论!!
#  已抓取60条评论!!
#  已抓取80条评论!!
#  已抓取100条评论!!
#  已抓取120条评论!!
#  已抓取140条评论!!
#  已抓取160条评论!!
#  已抓取180条评论!!
#  已抓取200条评论!!
#  已抓取218条评论!!
#  已抓取238条评论!!
#  已抓取257条评论!!
#  已抓取277条评论!!
#  已抓取297条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取317条评论!!
#  已抓取337条评论!!
#  已抓取353条评论!!
#  已抓取368条评论!!
#  已抓取387条评论!!
#  已抓取398条评论!!
#  已抓取403条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取417条评论!!
#  已抓取432条评论!!
#  已抓取442条评论!!
#  已抓取462条评论!!
#  已抓取473条评论!!
# 四川为了丁真有多努力抓取结束!
#
# 抓取热度:哈哈哈哈哈囧囧囧囧囧
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-db7fe5da699a> in <module>
# ----> 1 weibo_grap(20)
#
# <ipython-input-56-7896ec61ac9f> in weibo_grap(num)
#       1 def weibo_grap(num=5):
# ----> 2     set_grap(num)
#
# <ipython-input-55-7b4508f06520> in set_grap(question_num)
#      18                 print("因热度关键词一致, 故抓取结束!")
#      19                 return
# ---> 20         web_grap(keyword_list[i])
#      21         i += 1
#      22         question_num -= 1
#
# <ipython-input-53-3c78a02accec> in web_grap(keyword)
#      33             url = base_url.format(mid_list[i], mid_list[i], max_id)
#      34             # print(url)
# ---> 35             random_sleep()
#      36             res = requests.get(url, cookies=cookie, headers=random_header())
#      37             temp, contents_list = get_info(res, keyword)
#
# <ipython-input-48-d46a506c23ad> in random_sleep()
#       4     sleep_time = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.5, 1.6, 1.7, 1.8, 1.9, 2.0]
#       5     index = randint(0, len(sleep_time)-1)
# ----> 6     sleep(sleep_time[index])
#
# KeyboardInterrupt:

# %%
content = all_es_search()
    # 打印内容
title_print(content)
# Out:
#   搜索结果:
#     1. 男腾讯恋和爱姬艺
#     2. 哈哈哈哈哈
#     3. 钟南山称已出现同患流感和新冠病例
#     4. 王耀庆恶搞GQ封面
#     5. 李现 我有点无法fu吸
#     6. 少年的你将代表香港角逐奥斯卡
#     7. 多部委提方案消除老年数字鸿沟
#     8. 现实版搞笑一家人
#     9. 四川为了丁真有多努力
#     10. 杨惠妍连续4年蝉联中国女首富

# %%
web_grap("家长举报老师索贿信息被泄露")
# Out:
# 抓取热度:家长举报老师索贿信息被泄露
#  已抓取20条评论!!
#  已抓取40条评论!!
#  已抓取60条评论!!
#  已抓取80条评论!!
#  已抓取100条评论!!
#  已抓取120条评论!!
#  已抓取140条评论!!
#  已抓取159条评论!!
#  已抓取179条评论!!
#  已抓取198条评论!!
#  已抓取218条评论!!
#  已抓取237条评论!!
#  已抓取255条评论!!
#  已抓取273条评论!!
#  已抓取293条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
#  已抓取312条评论!!
#  已抓取331条评论!!
#  已抓取350条评论!!
#  已抓取369条评论!!
#  已抓取388条评论!!
#  已抓取406条评论!!
#  已抓取426条评论!!
#  已抓取445条评论!!
#  已抓取463条评论!!
#  已抓取482条评论!!
#  已抓取502条评论!!
#  已抓取506条评论!!
#  已抓取515条评论!!
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   再次申请...
# ip被封!, 等候20s
#   跳出此次申请...
# 家长举报老师索贿信息被泄露抓取结束!

# %%
content = es_search("家长举报老师索贿信息被泄露", stype="match_phrase", source=("describe",))
content_info = get_search_info(content, source=("describe",))
print("数据数量:{}".format(len(content_info)))
save_csv(content_info)
# Out:
# 数据数量:515
